# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests as req
from config import weather_api_key 
from datetime import datetime

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
#lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = req.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        current_weather = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": current_weather,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | najran
# Processing Record 2 of Set 1 | new norfolk
# Processing Record 3 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 1 | conceicao do araguaia
# Processing Record 5 of Set 1 | mangrol
# Processing Record 6 of Set 1 | bambous virieux
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | barrow
# Processing Record 14 of Set 1 | hithadhoo
# Processing Record 15 of Set 1 | thompson
# Processing Record 16 of Set 1 | diego de almagro
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | narsaq
# Processing Record 19 of Set 1 | araguacu
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 1 | iqaluit
# Processing Record 23 of Set 1 | hobart
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | cherbourg
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | dingle
# Processing Record 28 of Set 1 | atuona
# Processing Record 29 of Set 1 | nuqui
# Processing Record 30 of Set 1 | tasiilaq
# Processing Record 31 of Set 1 | qaanaaq
# Processing Record 32 of Set 1 | karasburg
# Processing Record 33 of Set 1 | college
# Processing Record 34 of Set 1 | yulara
# Processing Record 35 of Set 1 | geraldton
# Processing Record 36 of Set 1 | biltine
# Processing Record 37 of Set 1 | strezhevoy
# Processing Record 38 of Set 1 | kharp
# Processing Record 39 of Set 1 | bethel
# Processing Record 40 of Set 1 | khatanga
# Processing Record 41 of Set 1 | pangnirtung
# Processing Record 42 of Set 1 | lebu
# Processing Record 43 of Set 1 | puerto ayora
# Processing Record 44 of Set 1 | santa maria
# Processing Record 45 of Set 1 | brae
# Processing Record 46 of Set 1 | vila franca do campo
# Processing Record 47 of Set 1 | constitucion
# Processing Record 48 of Set 1 | tabuk
# Processing Record 49 of Set 1 | bilibino
# Processing Record 50 of Set 1 | rapid valley
# Processing Record 1 of Set 2 | cherskiy
# Processing Record 2 of Set 2 | kudahuvadhoo
# Processing Record 3 of Set 2 | lagoa
# Processing Record 4 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 2 | lundazi
# Processing Record 6 of Set 2 | opuwo
# Processing Record 7 of Set 2 | hermanus
# Processing Record 8 of Set 2 | lasa
# Processing Record 9 of Set 2 | avarua
# Processing Record 10 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 2 | caborca
# Processing Record 12 of Set 2 | nanortalik
# Processing Record 13 of Set 2 | saskylakh
# Processing Record 14 of Set 2 | ilulissat
# Processing Record 15 of Set 2 | bredasdorp
# Processing Record 16 of Set 2 | ribeira grande
# Processing Record 17 of Set 2 | kanniyakumari
# Processing Record 18 of Set 2 | kapaa
# Processing Record 19 of Set 2 | ponta do sol
# Processing Record 20 of Set 2 | tiksi
# Processing Record 21 of Set 2 | sunbury
# Processing Record 22 of Set 2 | bluff
# Processing Record 23 of Set 2 | lawigan
# Processing Record 24 of Set 2 | masunga
# Processing Record 25 of Set 2 | sitka
# Processing Record 26 of Set 2 | hasaki
# Processing Record 27 of Set 2 | leningradskiy
# Processing Record 28 of Set 2 | port alfred
# Processing Record 29 of Set 2 | coihaique
# Processing Record 30 of Set 2 | cidreira
# Processing Record 31 of Set 2 | santa maria del oro
# Processing Record 32 of Set 2 | galle
# Processing Record 33 of Set 2 | mar del plata
# Processing Record 34 of Set 2 | voi
# Processing Record 35 of Set 2 | bubaque
# Processing Record 36 of Set 2 | touros
# Processing Record 37 of Set 2 | upernavik
# Processing Record 38 of Set 2 | phan thiet
# Processing Record 39 of Set 2 | yarim
# Processing Record 40 of Set 2 | poum
# Processing Record 41 of Set 2 | guerrero negro
# Processing Record 42 of Set 2 | saint-philippe
# Processing Record 43 of Set 2 | westpunt
# City not found. Skipping...
# Processing Record 44 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 2 | okhotsk
# Processing Record 46 of Set 2 | jamestown
# Processing Record 47 of Set 2 | cape town
# Processing Record 48 of Set 2 | severo-kurilsk
# Processing Record 49 of Set 2 | uruguaiana
# Processing Record 50 of Set 2 | luba
# Processing Record 1 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 3 of Set 3 | havre-saint-pierre
# Processing Record 4 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 5 of Set 3 | kawana waters
# City not found. Skipping...
# Processing Record 6 of Set 3 | castro
# Processing Record 7 of Set 3 | tubruq
# City not found. Skipping...
# Processing Record 8 of Set 3 | bow island
# Processing Record 9 of Set 3 | severnyy-kospashskiy
# Processing Record 10 of Set 3 | nome
# Processing Record 11 of Set 3 | chunhuhub
# Processing Record 12 of Set 3 | east london
# Processing Record 13 of Set 3 | na wa
# Processing Record 14 of Set 3 | korla
# Processing Record 15 of Set 3 | metro
# Processing Record 16 of Set 3 | eureka
# Processing Record 17 of Set 3 | nicoya
# Processing Record 18 of Set 3 | broken hill
# Processing Record 19 of Set 3 | pisco
# Processing Record 20 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 3 | evensk
# Processing Record 22 of Set 3 | mahibadhoo
# Processing Record 23 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 3 | hilo
# Processing Record 25 of Set 3 | gamba
# Processing Record 26 of Set 3 | houston
# Processing Record 27 of Set 3 | salto de agua
# Processing Record 28 of Set 3 | ahipara
# Processing Record 29 of Set 3 | yerofey pavlovich
# Processing Record 30 of Set 3 | amboasary
# Processing Record 31 of Set 3 | shahreza
# Processing Record 32 of Set 3 | arona
# Processing Record 33 of Set 3 | okitipupa
# Processing Record 34 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 3 | katsuura
# Processing Record 36 of Set 3 | mount isa
# Processing Record 37 of Set 3 | bengkulu
# Processing Record 38 of Set 3 | olafsvik
# Processing Record 39 of Set 3 | eston
# Processing Record 40 of Set 3 | atar
# Processing Record 41 of Set 3 | vieques
# Processing Record 42 of Set 3 | canita
# Processing Record 43 of Set 3 | los llanos de aridane
# Processing Record 44 of Set 3 | beringovskiy
# Processing Record 45 of Set 3 | tha mai
# Processing Record 46 of Set 3 | mnogovershinnyy
# Processing Record 47 of Set 3 | jutai
# Processing Record 48 of Set 3 | ugoofaaru
# Processing Record 49 of Set 3 | road town
# Processing Record 50 of Set 3 | clyde river
# Processing Record 1 of Set 4 | cap malheureux
# Processing Record 2 of Set 4 | san juan
# Processing Record 3 of Set 4 | roald
# Processing Record 4 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 5 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 4 | haifa
# Processing Record 7 of Set 4 | arraial do cabo
# Processing Record 8 of Set 4 | japura
# Processing Record 9 of Set 4 | guinabsan
# Processing Record 10 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 4 | port angeles
# Processing Record 12 of Set 4 | port elizabeth
# Processing Record 13 of Set 4 | langenburg
# Processing Record 14 of Set 4 | yumen
# Processing Record 15 of Set 4 | dikson
# Processing Record 16 of Set 4 | hofn
# Processing Record 17 of Set 4 | chuy
# Processing Record 18 of Set 4 | taitung
# Processing Record 19 of Set 4 | margate
# Processing Record 20 of Set 4 | portobelo
# Processing Record 21 of Set 4 | mehamn
# Processing Record 22 of Set 4 | kandrian
# Processing Record 23 of Set 4 | pevek
# Processing Record 24 of Set 4 | gravdal
# Processing Record 25 of Set 4 | ginda
# Processing Record 26 of Set 4 | sao gabriel da cachoeira
# Processing Record 27 of Set 4 | san patricio
# Processing Record 28 of Set 4 | diffa
# Processing Record 29 of Set 4 | hailar
# Processing Record 30 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 4 | richards bay
# Processing Record 32 of Set 4 | cumra
# Processing Record 33 of Set 4 | alofi
# Processing Record 34 of Set 4 | saint-augustin
# Processing Record 35 of Set 4 | novobirilyussy
# Processing Record 36 of Set 4 | lingao
# Processing Record 37 of Set 4 | sakakah
# Processing Record 38 of Set 4 | zomba
# Processing Record 39 of Set 4 | kuopio
# Processing Record 40 of Set 4 | deputatskiy
# Processing Record 41 of Set 4 | ternate
# Processing Record 42 of Set 4 | huanren
# Processing Record 43 of Set 4 | tilichiki
# Processing Record 44 of Set 4 | pokhara
# Processing Record 45 of Set 4 | ballina
# Processing Record 46 of Set 4 | besikduzu
# Processing Record 47 of Set 4 | anloga
# Processing Record 48 of Set 4 | copala
# Processing Record 49 of Set 4 | port augusta
# Processing Record 50 of Set 4 | carnarvon
# Processing Record 1 of Set 5 | mayo
# Processing Record 2 of Set 5 | tashtyp
# Processing Record 3 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 5 | longyearbyen
# Processing Record 5 of Set 5 | ajdabiya
# Processing Record 6 of Set 5 | port-gentil
# Processing Record 7 of Set 5 | ketchikan
# Processing Record 8 of Set 5 | chokurdakh
# Processing Record 9 of Set 5 | cayenne
# Processing Record 10 of Set 5 | kavieng
# Processing Record 11 of Set 5 | luderitz
# Processing Record 12 of Set 5 | jalu
# Processing Record 13 of Set 5 | sao joao da barra
# Processing Record 14 of Set 5 | nelson bay
# Processing Record 15 of Set 5 | buariki
# City not found. Skipping...
# Processing Record 16 of Set 5 | bellavista
# Processing Record 17 of Set 5 | kodiak
# Processing Record 18 of Set 5 | hambantota
# Processing Record 19 of Set 5 | bathsheba
# Processing Record 20 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 5 | helong
# Processing Record 22 of Set 5 | villarrica
# Processing Record 23 of Set 5 | klaksvik
# Processing Record 24 of Set 5 | nikolskoye
# Processing Record 25 of Set 5 | kulhudhuffushi
# Processing Record 26 of Set 5 | esmeraldas
# Processing Record 27 of Set 5 | tessalit
# Processing Record 28 of Set 5 | kaitangata
# Processing Record 29 of Set 5 | gerash
# Processing Record 30 of Set 5 | newport
# Processing Record 31 of Set 5 | boueni
# Processing Record 32 of Set 5 | enkoping
# Processing Record 33 of Set 5 | puerto quijarro
# Processing Record 34 of Set 5 | yining
# Processing Record 35 of Set 5 | jaisalmer
# Processing Record 36 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 5 | cheuskiny
# City not found. Skipping...
# Processing Record 38 of Set 5 | changying
# Processing Record 39 of Set 5 | manzhouli
# Processing Record 40 of Set 5 | wilmington
# Processing Record 41 of Set 5 | labuhan
# Processing Record 42 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 43 of Set 5 | lompoc
# Processing Record 44 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 5 | saldanha
# Processing Record 46 of Set 5 | walvis bay
# Processing Record 47 of Set 5 | ayan
# Processing Record 48 of Set 5 | kurumkan
# Processing Record 49 of Set 5 | rosario
# Processing Record 50 of Set 5 | haimen
# Processing Record 1 of Set 6 | aykino
# Processing Record 2 of Set 6 | vangaindrano
# Processing Record 3 of Set 6 | noumea
# Processing Record 4 of Set 6 | kizilskoye
# Processing Record 5 of Set 6 | parras
# City not found. Skipping...
# Processing Record 6 of Set 6 | pergamino
# Processing Record 7 of Set 6 | biak
# Processing Record 8 of Set 6 | provideniya
# Processing Record 9 of Set 6 | airai
# Processing Record 10 of Set 6 | georgetown
# Processing Record 11 of Set 6 | marsa matruh
# Processing Record 12 of Set 6 | lakselv
# Processing Record 13 of Set 6 | ambilobe
# Processing Record 14 of Set 6 | belsand
# Processing Record 15 of Set 6 | the pas
# Processing Record 16 of Set 6 | lavrentiya
# Processing Record 17 of Set 6 | bontang
# Processing Record 18 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 6 | zemio
# Processing Record 20 of Set 6 | mandalgovi
# Processing Record 21 of Set 6 | garowe
# Processing Record 22 of Set 6 | hualmay
# Processing Record 23 of Set 6 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 24 of Set 6 | kosino
# Processing Record 25 of Set 6 | alta floresta
# Processing Record 26 of Set 6 | tyrma
# Processing Record 27 of Set 6 | san jose
# Processing Record 28 of Set 6 | sibut
# Processing Record 29 of Set 6 | samarai
# Processing Record 30 of Set 6 | cabo san lucas
# Processing Record 31 of Set 6 | puerto escondido
# Processing Record 32 of Set 6 | muroto
# Processing Record 33 of Set 6 | kavaratti
# Processing Record 34 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 35 of Set 6 | weyburn
# Processing Record 36 of Set 6 | victoria
# Processing Record 37 of Set 6 | burnie
# Processing Record 38 of Set 6 | maracacume
# Processing Record 39 of Set 6 | chom bung
# City not found. Skipping...
# Processing Record 40 of Set 6 | itoman
# Processing Record 41 of Set 6 | vestmanna
# Processing Record 42 of Set 6 | maceio
# Processing Record 43 of Set 6 | nagato
# Processing Record 44 of Set 6 | tuatapere
# Processing Record 45 of Set 6 | bandiagara
# Processing Record 46 of Set 6 | fortuna
# Processing Record 47 of Set 6 | kirakira
# Processing Record 48 of Set 6 | pervomayskiy
# Processing Record 49 of Set 6 | martapura
# Processing Record 50 of Set 6 | olinda
# Processing Record 1 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 2 of Set 7 | talnakh
# Processing Record 3 of Set 7 | port shepstone
# Processing Record 4 of Set 7 | dalvik
# Processing Record 5 of Set 7 | liman
# Processing Record 6 of Set 7 | port hedland
# Processing Record 7 of Set 7 | acapulco
# Processing Record 8 of Set 7 | burriana
# Processing Record 9 of Set 7 | sabha
# Processing Record 10 of Set 7 | mayumba
# Processing Record 11 of Set 7 | dondo
# Processing Record 12 of Set 7 | padang
# Processing Record 13 of Set 7 | plettenberg bay
# Processing Record 14 of Set 7 | rio gallegos
# Processing Record 15 of Set 7 | umm lajj
# Processing Record 16 of Set 7 | mahebourg
# Processing Record 17 of Set 7 | tall kayf
# Processing Record 18 of Set 7 | sur
# Processing Record 19 of Set 7 | ambulu
# Processing Record 20 of Set 7 | karratha
# Processing Record 21 of Set 7 | labytnangi
# Processing Record 22 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 23 of Set 7 | chapais
# Processing Record 24 of Set 7 | giyani
# Processing Record 25 of Set 7 | faanui
# Processing Record 26 of Set 7 | omboue
# Processing Record 27 of Set 7 | solnechnyy
# Processing Record 28 of Set 7 | bartlett
# Processing Record 29 of Set 7 | tuy hoa
# Processing Record 30 of Set 7 | kahului
# Processing Record 31 of Set 7 | kruisfontein
# Processing Record 32 of Set 7 | along
# Processing Record 33 of Set 7 | karamea
# City not found. Skipping...
# Processing Record 34 of Set 7 | nueva gerona
# Processing Record 35 of Set 7 | play cu
# City not found. Skipping...
# Processing Record 36 of Set 7 | flinders
# Processing Record 37 of Set 7 | wau
# Processing Record 38 of Set 7 | port blair
# Processing Record 39 of Set 7 | hongjiang
# Processing Record 40 of Set 7 | kerema
# Processing Record 41 of Set 7 | fairbanks
# Processing Record 42 of Set 7 | piranhas
# Processing Record 43 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 44 of Set 7 | busko-zdroj
# Processing Record 45 of Set 7 | jerantut
# Processing Record 46 of Set 7 | marabba
# Processing Record 47 of Set 7 | lazarev
# Processing Record 48 of Set 7 | bonavista
# Processing Record 49 of Set 7 | san cristobal
# Processing Record 50 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 1 of Set 8 | laela
# Processing Record 2 of Set 8 | laguna
# Processing Record 3 of Set 8 | torbay
# Processing Record 4 of Set 8 | ostersund
# Processing Record 5 of Set 8 | viisoara
# Processing Record 6 of Set 8 | ibipeba
# Processing Record 7 of Set 8 | honningsvag
# Processing Record 8 of Set 8 | khalkhal
# Processing Record 9 of Set 8 | krasnogorsk
# Processing Record 10 of Set 8 | mandali
# Processing Record 11 of Set 8 | maneadero
# Processing Record 12 of Set 8 | novikovo
# Processing Record 13 of Set 8 | cockburn town
# Processing Record 14 of Set 8 | azare
# Processing Record 15 of Set 8 | saint pete beach
# Processing Record 16 of Set 8 | mackay
# Processing Record 17 of Set 8 | nouadhibou
# Processing Record 18 of Set 8 | brownsville
# Processing Record 19 of Set 8 | saint george
# Processing Record 20 of Set 8 | vestmannaeyjar
# Processing Record 21 of Set 8 | mendoza
# Processing Record 22 of Set 8 | ancud
# Processing Record 23 of Set 8 | floro
# Processing Record 24 of Set 8 | salalah
# Processing Record 25 of Set 8 | byron bay
# Processing Record 26 of Set 8 | ouagadougou
# Processing Record 27 of Set 8 | qandala
# Processing Record 28 of Set 8 | benghazi
# Processing Record 29 of Set 8 | youghal
# Processing Record 30 of Set 8 | boende
# Processing Record 31 of Set 8 | cuamba
# Processing Record 32 of Set 8 | vostok
# Processing Record 33 of Set 8 | nara
# Processing Record 34 of Set 8 | price
# Processing Record 35 of Set 8 | tigzirt
# Processing Record 36 of Set 8 | tarauaca
# Processing Record 37 of Set 8 | dillon
# Processing Record 38 of Set 8 | avera
# Processing Record 39 of Set 8 | muzhi
# Processing Record 40 of Set 8 | waingapu
# Processing Record 41 of Set 8 | vanimo
# Processing Record 42 of Set 8 | yekaterinoslavka
# Processing Record 43 of Set 8 | charters towers
# Processing Record 44 of Set 8 | roma
# Processing Record 45 of Set 8 | tuktoyaktuk
# Processing Record 46 of Set 8 | snizhne
# Processing Record 47 of Set 8 | port lincoln
# Processing Record 48 of Set 8 | polyanka
# Processing Record 49 of Set 8 | cabedelo
# Processing Record 50 of Set 8 | west wendover
# Processing Record 1 of Set 9 | progreso
# Processing Record 2 of Set 9 | koshurnikovo
# Processing Record 3 of Set 9 | yashkul
# Processing Record 4 of Set 9 | katangli
# Processing Record 5 of Set 9 | esperance
# Processing Record 6 of Set 9 | isangel
# Processing Record 7 of Set 9 | san andres
# Processing Record 8 of Set 9 | ambon
# Processing Record 9 of Set 9 | naze
# Processing Record 10 of Set 9 | belmonte
# Processing Record 11 of Set 9 | taksimo
# Processing Record 12 of Set 9 | sioux lookout
# Processing Record 13 of Set 9 | komsomolskiy
# Processing Record 14 of Set 9 | buraydah
# Processing Record 15 of Set 9 | nyimba
# Processing Record 16 of Set 9 | vanavara
# Processing Record 17 of Set 9 | terney
# Processing Record 18 of Set 9 | sungaipenuh
# Processing Record 19 of Set 9 | troitskoye
# Processing Record 20 of Set 9 | tiarei
# Processing Record 21 of Set 9 | saint-louis
# Processing Record 22 of Set 9 | huarmey
# Processing Record 23 of Set 9 | pacific grove
# Processing Record 24 of Set 9 | codrington
# Processing Record 25 of Set 9 | saint-georges
# Processing Record 26 of Set 9 | el seibo
# Processing Record 27 of Set 9 | napa
# Processing Record 28 of Set 9 | pamfila
# Processing Record 29 of Set 9 | kidal
# Processing Record 30 of Set 9 | vardo
# Processing Record 31 of Set 9 | aklavik
# Processing Record 32 of Set 9 | manokwari
# Processing Record 33 of Set 9 | korampallam
# Processing Record 34 of Set 9 | sorland
# Processing Record 35 of Set 9 | nhulunbuy
# Processing Record 36 of Set 9 | gulshat
# City not found. Skipping...
# Processing Record 37 of Set 9 | tautira
# Processing Record 38 of Set 9 | henties bay
# Processing Record 39 of Set 9 | aswan
# Processing Record 40 of Set 9 | lithakia
# Processing Record 41 of Set 9 | seymchan
# Processing Record 42 of Set 9 | namatanai
# Processing Record 43 of Set 9 | haukipudas
# Processing Record 44 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 45 of Set 9 | ngunguru
# Processing Record 46 of Set 9 | rocha
# Processing Record 47 of Set 9 | ulaangom
# Processing Record 48 of Set 9 | mahon
# Processing Record 49 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 50 of Set 9 | winneba
# Processing Record 1 of Set 10 | lethem
# Processing Record 2 of Set 10 | pimentel
# Processing Record 3 of Set 10 | finschhafen
# Processing Record 4 of Set 10 | souillac
# Processing Record 5 of Set 10 | bitung
# Processing Record 6 of Set 10 | westport
# Processing Record 7 of Set 10 | ler
# Processing Record 8 of Set 10 | buchanan
# Processing Record 9 of Set 10 | ekibastuz
# Processing Record 10 of Set 10 | jvari
# Processing Record 11 of Set 10 | cordoba
# Processing Record 12 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 13 of Set 10 | buin
# Processing Record 14 of Set 10 | kasane
# Processing Record 15 of Set 10 | bowen
# Processing Record 16 of Set 10 | nuuk
# Processing Record 17 of Set 10 | berbera
# Processing Record 18 of Set 10 | lorengau
# Processing Record 19 of Set 10 | luanda
# Processing Record 20 of Set 10 | humaita
# Processing Record 21 of Set 10 | parabel
# Processing Record 22 of Set 10 | nichinan
# Processing Record 23 of Set 10 | el dorado
# Processing Record 24 of Set 10 | caernarfon
# Processing Record 25 of Set 10 | bima
# Processing Record 26 of Set 10 | nyurba
# Processing Record 27 of Set 10 | boguchany
# Processing Record 28 of Set 10 | turukhansk
# Processing Record 29 of Set 10 | borama
# City not found. Skipping...
# Processing Record 30 of Set 10 | ostrovnoy
# Processing Record 31 of Set 10 | bismarck
# Processing Record 32 of Set 10 | bagdarin
# Processing Record 33 of Set 10 | kajaani
# Processing Record 34 of Set 10 | znamenskoye
# Processing Record 35 of Set 10 | comodoro rivadavia
# Processing Record 36 of Set 10 | aktash
# Processing Record 37 of Set 10 | faya
# Processing Record 38 of Set 10 | thoen
# Processing Record 39 of Set 10 | katherine
# Processing Record 40 of Set 10 | terme
# Processing Record 41 of Set 10 | luwuk
# Processing Record 42 of Set 10 | bibbiena
# Processing Record 43 of Set 10 | sindor
# Processing Record 44 of Set 10 | north las vegas
# Processing Record 45 of Set 10 | viedma
# Processing Record 46 of Set 10 | nalut
# Processing Record 47 of Set 10 | niteroi
# Processing Record 48 of Set 10 | panaba
# Processing Record 49 of Set 10 | dallas
# Processing Record 50 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 1 of Set 11 | nybro
# Processing Record 2 of Set 11 | snyder
# Processing Record 3 of Set 11 | salvador
# Processing Record 4 of Set 11 | roebourne
# Processing Record 5 of Set 11 | san angelo
# Processing Record 6 of Set 11 | lima
# Processing Record 7 of Set 11 | maputo
# Processing Record 8 of Set 11 | fuling
# Processing Record 9 of Set 11 | sao filipe
# Processing Record 10 of Set 11 | key west
# Processing Record 11 of Set 11 | varadero
# Processing Record 12 of Set 11 | kalmunai
# Processing Record 13 of Set 11 | liku
# Processing Record 14 of Set 11 | osorno
# Processing Record 15 of Set 11 | semnan
# Processing Record 16 of Set 11 | strathpeffer
# Processing Record 17 of Set 11 | tual
# Processing Record 18 of Set 11 | votkinsk
# Processing Record 19 of Set 11 | rio grande
# Processing Record 20 of Set 11 | nemuro
# Processing Record 21 of Set 11 | jiamusi
# Processing Record 22 of Set 11 | sunds
# Processing Record 23 of Set 11 | hay river
# Processing Record 24 of Set 11 | inhuma
# Processing Record 25 of Set 11 | uvira
# Processing Record 26 of Set 11 | natal
# Processing Record 27 of Set 11 | egvekinot
# Processing Record 28 of Set 11 | san miguel
# Processing Record 29 of Set 11 | atasu
# Processing Record 30 of Set 11 | kabare
# Processing Record 31 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 11 | capoterra
# Processing Record 33 of Set 11 | seoul
# Processing Record 34 of Set 11 | ciudad bolivar
# Processing Record 35 of Set 11 | aksarka
# Processing Record 36 of Set 11 | morant bay
# Processing Record 37 of Set 11 | champerico
# Processing Record 38 of Set 11 | hirara
# Processing Record 39 of Set 11 | banjar
# Processing Record 40 of Set 11 | paranavai
# Processing Record 41 of Set 11 | jumla
# Processing Record 42 of Set 11 | ust-nera
# Processing Record 43 of Set 11 | tupik
# Processing Record 44 of Set 11 | berlevag
# Processing Record 45 of Set 11 | nizhnyaya tavda
# Processing Record 46 of Set 11 | hendijan
# City not found. Skipping...
# Processing Record 47 of Set 11 | marawi
# Processing Record 48 of Set 11 | niimi
# Processing Record 49 of Set 11 | takoradi
# Processing Record 50 of Set 11 | dongobesh
# Processing Record 1 of Set 12 | tezu
# Processing Record 2 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record 3 of Set 12 | jaen
# Processing Record 4 of Set 12 | sobolevo
# Processing Record 5 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 12 | broome
# Processing Record 7 of Set 12 | husavik
# Processing Record 8 of Set 12 | mago
# Processing Record 9 of Set 12 | chama
# Processing Record 10 of Set 12 | kozulka
# Processing Record 11 of Set 12 | san clemente
# Processing Record 12 of Set 12 | bilma
# Processing Record 13 of Set 12 | akyab
# Processing Record 14 of Set 12 | guiratinga
# Processing Record 15 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 12 | rawson
# Processing Record 17 of Set 12 | calama
# Processing Record 18 of Set 12 | abay
# Processing Record 19 of Set 12 | nam tha
# City not found. Skipping...
# Processing Record 20 of Set 12 | odweyne
# Processing Record 21 of Set 12 | khash
# Processing Record 22 of Set 12 | sao miguel
# Processing Record 23 of Set 12 | batemans bay
# Processing Record 24 of Set 12 | verkhoyansk
# Processing Record 25 of Set 12 | athabasca
# Processing Record 26 of Set 12 | hvolsvollur
# Processing Record 27 of Set 12 | taphan hin
# Processing Record 28 of Set 12 | mantua
# Processing Record 29 of Set 12 | dixon
# Processing Record 30 of Set 12 | chifeng
# Processing Record 31 of Set 12 | kulu
# Processing Record 32 of Set 12 | hinjilikatu
# Processing Record 33 of Set 12 | hanstholm
# Processing Record 34 of Set 12 | manaus
# Processing Record 35 of Set 12 | edd
# Processing Record 36 of Set 12 | paracuru
# Processing Record 37 of Set 12 | marovoay
# Processing Record 38 of Set 12 | smithers
# Processing Record 39 of Set 12 | lupsanu
# Processing Record 40 of Set 12 | dunedin
# Processing Record 41 of Set 12 | hanzhong
# Processing Record 42 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 43 of Set 12 | clovis
# Processing Record 44 of Set 12 | grande prairie
# Processing Record 45 of Set 12 | raudeberg
# Processing Record 46 of Set 12 | san carlos
# Processing Record 47 of Set 12 | agua dulce
# Processing Record 48 of Set 12 | ramacca
# Processing Record 49 of Set 12 | hamilton
# Processing Record 50 of Set 12 | port hardy
# Processing Record 1 of Set 13 | taltal
# Processing Record 2 of Set 13 | kedougou
# Processing Record 3 of Set 13 | el carmen
# Processing Record 4 of Set 13 | akhmim
# Processing Record 5 of Set 13 | tekeli
# Processing Record 6 of Set 13 | crossfield
# Processing Record 7 of Set 13 | axim
# Processing Record 8 of Set 13 | tungkang
# City not found. Skipping...
# Processing Record 9 of Set 13 | veraval
# Processing Record 10 of Set 13 | komarno
# Processing Record 11 of Set 13 | half moon bay
# Processing Record 12 of Set 13 | fort nelson
# Processing Record 13 of Set 13 | calvinia
# Processing Record 14 of Set 13 | yabassi
# Processing Record 15 of Set 13 | inirida
# Processing Record 16 of Set 13 | longjiang
# Processing Record 17 of Set 13 | mossendjo
# Processing Record 18 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 19 of Set 13 | mujiayingzi
# Processing Record 20 of Set 13 | malanje
# Processing Record 21 of Set 13 | atoka
# Processing Record 22 of Set 13 | murchison
# Processing Record 23 of Set 13 | corlatel
# Processing Record 24 of Set 13 | renqiu
# Processing Record 25 of Set 13 | balaipungut
# Processing Record 26 of Set 13 | paamiut
# Processing Record 27 of Set 13 | lata
# Processing Record 28 of Set 13 | osmena
# Processing Record 29 of Set 13 | tahe
# Processing Record 30 of Set 13 | saint anthony
# Processing Record 31 of Set 13 | tiznit
# Processing Record 32 of Set 13 | xuddur
# Processing Record 33 of Set 13 | sayyan
# Processing Record 34 of Set 13 | ronneby
# Processing Record 35 of Set 13 | stokmarknes
# Processing Record 36 of Set 13 | oudtshoorn
# Processing Record 37 of Set 13 | shubarshi
# Processing Record 38 of Set 13 | elat
# Processing Record 39 of Set 13 | wanning
# Processing Record 40 of Set 13 | moose factory
# Processing Record 41 of Set 13 | porto belo
# Processing Record 42 of Set 13 | skjervoy
# Processing Record 43 of Set 13 | yabrud
# Processing Record 44 of Set 13 | luau
# Processing Record 45 of Set 13 | kazachinskoye
# Processing Record 46 of Set 13 | estrela
# Processing Record 47 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 48 of Set 13 | ormara
# Processing Record 49 of Set 13 | norman wells
# Processing Record 50 of Set 13 | idar-oberstein
# Processing Record 1 of Set 14 | hearst
# Processing Record 2 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 3 of Set 14 | springbok
# Processing Record 4 of Set 14 | bonthe
# Processing Record 5 of Set 14 | adeje
# Processing Record 6 of Set 14 | hanchuan
# Processing Record 7 of Set 14 | betioky
# Processing Record 8 of Set 14 | sasina
# Processing Record 9 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 14 | aleksandrov gay
# Processing Record 11 of Set 14 | capreol
# Processing Record 12 of Set 14 | aromashevo
# Processing Record 13 of Set 14 | mokhsogollokh
# Processing Record 14 of Set 14 | talaya
# Processing Record 15 of Set 14 | moba
# Processing Record 16 of Set 14 | tshikapa
# Processing Record 17 of Set 14 | bonfim
# Processing Record 18 of Set 14 | kamyshin
# Processing Record 19 of Set 14 | morondava
# Processing Record 20 of Set 14 | saint-pierre
# Processing Record 21 of Set 14 | praia da vitoria
# Processing Record 22 of Set 14 | iberia
# Processing Record 23 of Set 14 | nioki
# Processing Record 24 of Set 14 | bambanglipuro
# Processing Record 25 of Set 14 | tornio
# Processing Record 26 of Set 14 | namibe
# Processing Record 27 of Set 14 | atherton
# Processing Record 28 of Set 14 | tawang
# Processing Record 29 of Set 14 | bluefields
# Processing Record 30 of Set 14 | krasnoselkup
# Processing Record 31 of Set 14 | sheridan
# Processing Record 32 of Set 14 | jijiga
# Processing Record 33 of Set 14 | qaqortoq
# Processing Record 34 of Set 14 | corozal
# Processing Record 35 of Set 14 | maromitsa
# Processing Record 36 of Set 14 | marzuq
# Processing Record 37 of Set 14 | ziro
# Processing Record 38 of Set 14 | carballo
# Processing Record 39 of Set 14 | yokadouma
# Processing Record 40 of Set 14 | bull savanna
# Processing Record 41 of Set 14 | coquimbo
# Processing Record 42 of Set 14 | voh
# Processing Record 43 of Set 14 | visakhapatnam
# Processing Record 44 of Set 14 | rajanpur
# Processing Record 45 of Set 14 | asau
# Processing Record 46 of Set 14 | san buenaventura
# Processing Record 47 of Set 14 | ibague
# Processing Record 48 of Set 14 | pringsewu
# Processing Record 49 of Set 14 | saint-joseph
# Processing Record 50 of Set 14 | mount gambier
# Processing Record 1 of Set 15 | kuryk
# Processing Record 2 of Set 15 | port hawkesbury
# Processing Record 3 of Set 15 | gondar
# Processing Record 4 of Set 15 | itarema
# Processing Record 5 of Set 15 | canon city
# Processing Record 6 of Set 15 | maridi
# Processing Record 7 of Set 15 | harper
# Processing Record 8 of Set 15 | grindavik
# Processing Record 9 of Set 15 | gayny
# Processing Record 10 of Set 15 | sistranda
# Processing Record 11 of Set 15 | vila velha
# Processing Record 12 of Set 15 | araguaina
# Processing Record 13 of Set 15 | elizabeth city
# Processing Record 14 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 15 of Set 15 | santiago del estero
# Processing Record 16 of Set 15 | tonantins
# Processing Record 17 of Set 15 | ust-tsilma
# Processing Record 18 of Set 15 | siilinjarvi
# Processing Record 19 of Set 15 | ndjole
# Processing Record 20 of Set 15 | nampula
# Processing Record 21 of Set 15 | dzhebariki-khaya
# Processing Record 22 of Set 15 | zihuatanejo
# Processing Record 23 of Set 15 | kaeo
# Processing Record 24 of Set 15 | urucara
# Processing Record 25 of Set 15 | khani
# Processing Record 26 of Set 15 | toamasina
# Processing Record 27 of Set 15 | dicabisagan
# Processing Record 28 of Set 15 | kirillov
# Processing Record 29 of Set 15 | golpayegan
# Processing Record 30 of Set 15 | yazman
# Processing Record 31 of Set 15 | hami
# Processing Record 32 of Set 15 | balimo
# City not found. Skipping...
# Processing Record 33 of Set 15 | zhuhai
# Processing Record 34 of Set 15 | assiniboia
# Processing Record 35 of Set 15 | makat
# Processing Record 36 of Set 15 | asyut
# Processing Record 37 of Set 15 | waitati
# Processing Record 38 of Set 15 | san policarpo
# Processing Record 39 of Set 15 | havoysund
# Processing Record 40 of Set 15 | angra
# City not found. Skipping...
# Processing Record 41 of Set 15 | bukama
# Processing Record 42 of Set 15 | madang
# Processing Record 43 of Set 15 | aykhal
# Processing Record 44 of Set 15 | xining
# Processing Record 45 of Set 15 | saint-claude
# Processing Record 46 of Set 15 | caravelas
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 688

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                 Najran  17.4924   44.1277     65.05        16           1
# 1            New Norfolk -42.7826  147.0587     52.66        80           8
# 2  Conceicao Do Araguaia  -8.2578  -49.2647     83.79        56          96
# 3                Mangrol  21.1167   70.1167     78.66        64           4
# 4        Bambous Virieux -20.3428   57.7575     73.22        77          19
# 5           Punta Arenas -53.1500  -70.9167     50.11        62          20
# 6                  Vaini -21.2000 -175.2000     77.16        78          20
# 7            Yellowknife  62.4560 -114.3525     40.41       100          90
# 8                Ushuaia -54.8000  -68.3000     42.46        81          75
# 9                Mataura -46.1927  168.8643     60.46        74          92
#
#    Wind Speed Current Description Country                 Date
# 0        1.90           clear sky      SA  2021-10-26 21:43:15
# 1        2.53           clear sky      AU  2021-10-26 21:43:15
# 2        0.47     overcast clouds      BR  2021-10-26 21:43:16
# 3        5.01           clear sky      IN  2021-10-26 21:43:16
# 4       12.66          light rain      MU  2021-10-26 21:43:17
# 5       26.46          few clouds      CL  2021-10-26 21:38:43
# 6       13.80          few clouds      TO  2021-10-26 21:43:17
# 7        4.61                mist      CA  2021-10-26 21:41:23
# 8       31.07          light rain      AR  2021-10-26 21:43:18
# 9        0.65       moderate rain      NZ  2021-10-26 21:43:19

# %%
#city_data_df.info()

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0                 Najran      SA  17.4924   44.1277     65.05        16
# 1            New Norfolk      AU -42.7826  147.0587     52.66        80
# 2  Conceicao Do Araguaia      BR  -8.2578  -49.2647     83.79        56
# 3                Mangrol      IN  21.1167   70.1167     78.66        64
# 4        Bambous Virieux      MU -20.3428   57.7575     73.22        77
# 5           Punta Arenas      CL -53.1500  -70.9167     50.11        62
# 6                  Vaini      TO -21.2000 -175.2000     77.16        78
# 7            Yellowknife      CA  62.4560 -114.3525     40.41       100
# 8                Ushuaia      AR -54.8000  -68.3000     42.46        81
# 9                Mataura      NZ -46.1927  168.8643     60.46        74
#
#    Cloudiness  Wind Speed Current Description
# 0           1        1.90           clear sky
# 1           8        2.53           clear sky
# 2          96        0.47     overcast clouds
# 3           4        5.01           clear sky
# 4          19       12.66          light rain
# 5          20       26.46          few clouds
# 6          20       13.80          few clouds
# 7          90        4.61                mist
# 8          75       31.07          light rain
# 9          92        0.65       moderate rain

# %%
#Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
output_data_file= "../Weather_Database/WeatherPy_Database.csv"

city_data_df.to_csv(output_data_file, index_label="City_id")
